# %% [markdown]
# <a href="https://colab.research.google.com/github/bithi-6535/bithi-6535/blob/main/macine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor
train_data=pd.read_csv("/content/drive/MyDrive/Home Data.zip (Unzipped Files)/home_data_train.csv")
print(train_data.shape)
train_data.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
Y=train_data.SalePrice
features=['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath',
          'BedroomAbvGr','TotRmsAbvGrd']


X=train_data[features]
print(f"full X:{X.shape}")
print(f"fullY:{Y.shape}")
X_train, X_test,Y_train, Y_test=train_test_split(X,Y, train_size=0.8,
                                                 test_size=0.2,random_state=0)
print(f"X_train:{X_train.shape}")
print(f"X_test:{X_test.shape}")
print(f"Y_train:{Y_train.shape}")
print(f"Y_test:{Y_test.shape}")
# Out:
# full X:(1460, 7)
# fullY:(1460,)
# X_train:(1168, 7)
# X_test:(292, 7)
# Y_train:(1168,)
# Y_test:(292,)

# %%
model_1=RandomForestRegressor(n_estimators=50,random_state=0)
model_2=RandomForestRegressor(n_estimators=100,random_state=0)
model3=RandomForestRegressor(n_estimators=100,random_state=0,
                             criterion='absolute_error')
model_4=RandomForestRegressor(n_estimators=200,min_samples_split=20,
                              random_state=0)
model_5=RandomForestRegressor(n_estimators=100,max_depth=7,random_state=0)
models=[model_1,model_2,model3,model_4,model_5]

# %%
from sklearn.metrics import mean_absolute_error

# %%
def score_model(model,X_train,Y_train,Y_test):
               model.fit(X_train, Y_train)
               preds=model.predict(X_test)
               return mean_absolute_error(Y_test,preds)
for model in models:
  mae = score_model (model,X_train,Y_train,Y_test)
  print(f"MAE:{mae}")
# Out:
# MAE:24015.492818003917
# MAE:23740.979228636657
# MAE:23431.747157534246
# MAE:23996.676789668687
# MAE:23706.672864217904

# %%
features=['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr',
          'TotRmsAbvGrd']
X=train_data[features]
print(f"full X:{X.shape}")
print(f"full Y:{Y.shape} \n")
# Out:
# full X:(1460, 7)
# full Y:(1460,)

# %%
from sklearn.model_selection import train_test_split
obj_cols=[col for col in  X.columns if X[col].dtype=='object']
ordinal_encoder=OrdinalEncoder()
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,train_size=0.8,
                                                  test_size=0.2,
                                                  random_state=0)
X[obj_cols]=ordinal_encoder.fit_transform(X[obj_cols])
X_train,y_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8,test_size=0.2,
                                               random_state=0)

X_train.head()
# Out:
#      LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 618    11694       2007      1828         0         2             3
# 870     6600       1962       894         0         1             2
# 92     13360       1921       964         0         1             2
# 817    13265       2002      1689         0         2             3
# 302    13704       2001      1541         0         2             3
#
#      TotRmsAbvGrd
# 618             9
# 870             5
# 92              5
# 817             7
# 302             6
